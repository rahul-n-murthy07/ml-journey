# %%
import pandas as pd

# %%
import pandas as pd

# Read the CSV file
df = pd.read_csv(r"C:\Users\RAHUL N MURTHY\Downloads\weather.csv", parse_dates=['Date'])

# Print the first few rows
print(df)
# Out:
#          Date       City  Temperature  Humidity  WindSpeed  Precipitation  \
# 0  2024-01-01  Bangalore         22.5      65.0        8.2            0.0
# 1  2024-01-01     Mumbai         28.1      78.0       12.5            0.0
# 2  2024-01-01      Delhi         12.3      82.0        5.1            0.0
# 3  2024-01-01    Chennai         26.8      75.0       10.3            0.0
# 4  2024-01-01    Kolkata         18.5      70.0        7.8            0.0
# 5  2024-01-02  Bangalore         23.1      62.0        9.0            0.0
# 6  2024-01-02     Mumbai         28.5      80.0       11.8            2.3
# 7  2024-01-02      Delhi         11.8      85.0        4.5            0.0
# 8  2024-01-02    Chennai         27.2      73.0       11.1            0.0
# 9  2024-01-02    Kolkata         19.0      68.0        8.5            0.0
# 10 2024-01-03  Bangalore         21.8      68.0        7.5            1.2
# 11 2024-01-03     Mumbai         29.0      82.0       13.2            5.6
# ...

# %%
print(df.shape)
# Out:
# (50, 7)

# %%
rows , columns = df.shape 
rows

columns
# Out:
# 7

# %%
columns
# Out:
# 7

# %%
df.head(10)
# Out:
#         Date       City  Temperature  Humidity  WindSpeed  Precipitation  \
# 0 2024-01-01  Bangalore         22.5      65.0        8.2            0.0
# 1 2024-01-01     Mumbai         28.1      78.0       12.5            0.0
# 2 2024-01-01      Delhi         12.3      82.0        5.1            0.0
# 3 2024-01-01    Chennai         26.8      75.0       10.3            0.0
# 4 2024-01-01    Kolkata         18.5      70.0        7.8            0.0
# 5 2024-01-02  Bangalore         23.1      62.0        9.0            0.0
# 6 2024-01-02     Mumbai         28.5      80.0       11.8            2.3
# 7 2024-01-02      Delhi         11.8      85.0        4.5            0.0
# 8 2024-01-02    Chennai         27.2      73.0       11.1            0.0
# 9 2024-01-02    Kolkata         19.0      68.0        8.5            0.0
#
#   Condition
# 0     Sunny
# 1    Cloudy
# 2     Foggy
# 3     Sunny
# 4    Cloudy
# 5     Sunny
# 6     Rainy
# 7     Foggy
# 8     Sunny
# 9     Sunny

# %%
df.tail(10)
# Out:
#          Date       City  Temperature  Humidity  WindSpeed  Precipitation  \
# 40 2024-01-09  Bangalore         21.5      72.0        7.8            3.5
# 41 2024-01-09     Mumbai         28.0      81.0       11.8            4.2
# 42 2024-01-09      Delhi         13.8      83.0        5.2            0.0
# 43 2024-01-09    Chennai         26.2      76.0       10.0            2.8
# 44 2024-01-09    Kolkata         18.8      71.0        7.5            0.0
# 45 2024-01-10  Bangalore         22.5      66.0        8.4            0.0
# 46 2024-01-10     Mumbai         28.5      76.0       12.1            0.0
# 47 2024-01-10      Delhi         14.8      73.0        5.9            0.0
# 48 2024-01-10    Chennai         27.5      73.0       10.7            0.0
# 49 2024-01-10    Kolkata         19.5      65.0        8.4            0.0
#
#    Condition
# 40     Rainy
# 41     Rainy
# 42     Foggy
# 43     Rainy
# 44    Cloudy
# 45    Cloudy
# 46     Sunny
# 47     Sunny
# 48     Sunny
# ...

# %%
df[2:10:2]
# Out:
#         Date     City  Temperature  Humidity  WindSpeed  Precipitation  \
# 2 2024-01-01    Delhi         12.3      82.0        5.1            0.0
# 4 2024-01-01  Kolkata         18.5      70.0        7.8            0.0
# 6 2024-01-02   Mumbai         28.5      80.0       11.8            2.3
# 8 2024-01-02  Chennai         27.2      73.0       11.1            0.0
#
#   Condition
# 2     Foggy
# 4    Cloudy
# 6     Rainy
# 8     Sunny

# %%
df.columns
# Out:
# Index(['Date', 'City', 'Temperature', 'Humidity', 'WindSpeed', 'Precipitation',
#        'Condition'],
#       dtype='str')

# %%
df.Date
# Out:
# 0    2024-01-01
# 1    2024-01-01
# 2    2024-01-01
# 3    2024-01-01
# 4    2024-01-01
# 5    2024-01-02
# 6    2024-01-02
# 7    2024-01-02
# 8    2024-01-02
# 9    2024-01-02
# 10   2024-01-03
# 11   2024-01-03
# 12   2024-01-03
# 13   2024-01-03
# 14   2024-01-03
# 15   2024-01-04
# 16   2024-01-04
# 17   2024-01-04
# 18   2024-01-04
# 19   2024-01-04
# 20   2024-01-05
# 21   2024-01-05
# 22   2024-01-05
# 23   2024-01-05
# 24   2024-01-05
# 25   2024-01-06
# 26   2024-01-06
# 27   2024-01-06
# 28   2024-01-06
# 29   2024-01-06
# 30   2024-01-07
# 31   2024-01-07
# 32   2024-01-07
# 33   2024-01-07
# 34   2024-01-07
# 35   2024-01-08
# 36   2024-01-08
# 37   2024-01-08
# 38   2024-01-08
# 39   2024-01-08
# 40   2024-01-09
# 41   2024-01-09
# 42   2024-01-09
# 43   2024-01-09
# 44   2024-01-09
# 45   2024-01-10
# 46   2024-01-10
# 47   2024-01-10
# 48   2024-01-10
# 49   2024-01-10
# Name: Date, dtype: datetime64[us]

# %%
df[['Date', 'City']]
# Out:
#          Date       City
# 0  2024-01-01  Bangalore
# 1  2024-01-01     Mumbai
# 2  2024-01-01      Delhi
# 3  2024-01-01    Chennai
# 4  2024-01-01    Kolkata
# 5  2024-01-02  Bangalore
# 6  2024-01-02     Mumbai
# 7  2024-01-02      Delhi
# 8  2024-01-02    Chennai
# 9  2024-01-02    Kolkata
# 10 2024-01-03  Bangalore
# 11 2024-01-03     Mumbai
# 12 2024-01-03      Delhi
# 13 2024-01-03    Chennai
# 14 2024-01-03    Kolkata
# 15 2024-01-04  Bangalore
# 16 2024-01-04     Mumbai
# 17 2024-01-04      Delhi
# 18 2024-01-04    Chennai
# 19 2024-01-04    Kolkata
# 20 2024-01-05  Bangalore
# 21 2024-01-05     Mumbai
# 22 2024-01-05      Delhi
# 23 2024-01-05    Chennai
# 24 2024-01-05    Kolkata
# 25 2024-01-06  Bangalore
# 26 2024-01-06     Mumbai
# 27 2024-01-06      Delhi
# 28 2024-01-06    Chennai
# 29 2024-01-06    Kolkata
# 30 2024-01-07  Bangalore
# 31 2024-01-07     Mumbai
# 32 2024-01-07      Delhi
# 33 2024-01-07    Chennai
# 34 2024-01-07    Kolkata
# 35 2024-01-08  Bangalore
# ...

# %%
df[df.WindSpeed>= 11.0]
# Out:
#          Date     City  Temperature  Humidity  WindSpeed  Precipitation  \
# 1  2024-01-01   Mumbai         28.1      78.0       12.5            0.0
# 6  2024-01-02   Mumbai         28.5      80.0       11.8            2.3
# 8  2024-01-02  Chennai         27.2      73.0       11.1            0.0
# 11 2024-01-03   Mumbai         29.0      82.0       13.2            5.6
# 16 2024-01-04   Mumbai         27.8      79.0       12.0            0.0
# 21 2024-01-05   Mumbai         28.3      77.0       11.5            0.0
# 23 2024-01-05  Chennai         28.0      72.0       11.0            0.0
# 26 2024-01-06   Mumbai         29.2      75.0       12.8            0.0
# 28 2024-01-06  Chennai         28.5      71.0       11.3            0.0
# 31 2024-01-07   Mumbai         28.8      78.0       12.2            1.1
# 36 2024-01-08   Mumbai         29.5      73.0       13.0            0.0
# 38 2024-01-08  Chennai         28.2      70.0       11.2            0.0
# ...

# %%
import pandas as pd 
bf = pd.read_excel(r"C:\Users\RAHUL N MURTHY\Downloads\ecommerce_practice.xlsx",
                   sheet_name="Orders",
                   parse_dates=['OrderDate'])

# %%
print (bf.head())
# Out:
#     OrderID CustomerID ProductID  OrderDate       City     Category  Quantity  \
# 0  ORD00001    CUST039   PROD015 2024-01-01     Mumbai         Toys         3
# 1  ORD00002    CUST029   PROD027 2024-01-02  Hyderabad  Electronics         4
# 2  ORD00003    CUST015   PROD022 2024-01-04  Hyderabad       Beauty         1
# 3  ORD00004    CUST043   PROD024 2024-01-06  Bangalore         Toys         5
# 4  ORD00005    CUST008   PROD009 2024-01-08  Hyderabad    Furniture         5
#
#    UnitPrice  Discount  TotalAmount  PaymentMode     Status  Rating
# 0    5334.57      0.20     12802.97   Debit Card  Delivered     5.0
# 1   45146.13      0.05    171555.29  Net Banking  Cancelled     3.0
# 2   25360.57      0.15     21556.48  Credit Card  Delivered     3.0
# 3   41356.58      0.05    196443.76  Credit Card  Delivered     5.0
# 4   16137.47      0.20     64549.88  Net Banking    Pending     5.0

# %%
import os 
import pandas as pd 
os.chdir(r"C:\Users\RAHUL N MURTHY\Downloads")

# %%
bf = pd.read_excel("ecommerce_practice.xlsx")
print(bf.head())
# Out:
#     OrderID CustomerID ProductID   OrderDate       City     Category  \
# 0  ORD00001    CUST039   PROD015  2024-01-01     Mumbai         Toys
# 1  ORD00002    CUST029   PROD027  2024-01-02  Hyderabad  Electronics
# 2  ORD00003    CUST015   PROD022  2024-01-04  Hyderabad       Beauty
# 3  ORD00004    CUST043   PROD024  2024-01-06  Bangalore         Toys
# 4  ORD00005    CUST008   PROD009  2024-01-08  Hyderabad    Furniture
#
#    Quantity  UnitPrice  Discount  TotalAmount  PaymentMode     Status  Rating
# 0         3    5334.57      0.20     12802.97   Debit Card  Delivered     5.0
# 1         4   45146.13      0.05    171555.29  Net Banking  Cancelled     3.0
# 2         1   25360.57      0.15     21556.48  Credit Card  Delivered     3.0
# 3         5   41356.58      0.05    196443.76  Credit Card  Delivered     5.0
# 4         5   16137.47      0.20     64549.88  Net Banking    Pending     5.0

# %%
df = pd.read_excel("ecommerce_practice.xlsx", sheet_name="Orders")

print(df)              # print entire DataFrame
print(df.head())       # first 5 rows (default)
print(df.head(10))     # first 10 rows
print(df.tail())       # last 5 rows
print(df.tail(10))     # last 10 rows
# Out:
#       OrderID CustomerID ProductID   OrderDate       City        Category  \
# 0    ORD00001    CUST039   PROD015  2024-01-01     Mumbai            Toys
# 1    ORD00002    CUST029   PROD027  2024-01-02  Hyderabad     Electronics
# 2    ORD00003    CUST015   PROD022  2024-01-04  Hyderabad          Beauty
# 3    ORD00004    CUST043   PROD024  2024-01-06  Bangalore            Toys
# 4    ORD00005    CUST008   PROD009  2024-01-08  Hyderabad       Furniture
# ..        ...        ...       ...         ...        ...             ...
# 195  ORD00196    CUST037   PROD030  2024-12-23       Pune       Furniture
# 196  ORD00197    CUST033   PROD029  2024-12-25  Bangalore  Home & Kitchen
# 197  ORD00198    CUST042   PROD014  2024-12-27      Delhi            Toys
# 198  ORD00199    CUST044   PROD021  2024-12-29  Bangalore          Beauty
# 199  ORD00200    CUST024   PROD006  2024-12-31      Delhi       Furniture
#
#      Quantity  UnitPrice  Discount  TotalAmount  PaymentMode     Status  \
# ...

# %%
df = pd.read_excel("ecommerce_practice.xlsx", sheet_name=0)

print(df)              # print entire DataFrame
print(df.head())       # first 5 rows (default)
print(df.head(10))     # first 10 rows
print(df.tail())       # last 5 rows
print(df.tail(10))     # last 10 rows
# Out:
#       OrderID CustomerID ProductID   OrderDate       City        Category  \
# 0    ORD00001    CUST039   PROD015  2024-01-01     Mumbai            Toys
# 1    ORD00002    CUST029   PROD027  2024-01-02  Hyderabad     Electronics
# 2    ORD00003    CUST015   PROD022  2024-01-04  Hyderabad          Beauty
# 3    ORD00004    CUST043   PROD024  2024-01-06  Bangalore            Toys
# 4    ORD00005    CUST008   PROD009  2024-01-08  Hyderabad       Furniture
# ..        ...        ...       ...         ...        ...             ...
# 195  ORD00196    CUST037   PROD030  2024-12-23       Pune       Furniture
# 196  ORD00197    CUST033   PROD029  2024-12-25  Bangalore  Home & Kitchen
# 197  ORD00198    CUST042   PROD014  2024-12-27      Delhi            Toys
# 198  ORD00199    CUST044   PROD021  2024-12-29  Bangalore          Beauty
# 199  ORD00200    CUST024   PROD006  2024-12-31      Delhi       Furniture
#
#      Quantity  UnitPrice  Discount  TotalAmount  PaymentMode     Status  \
# ...

# %%
all_sheets = pd.read_excel("ecommerce_practice.xlsx",sheet_name= None )
print (all_sheets.keys())
Products= all_sheets["Products"]
print(Products.head())
# Out:
# dict_keys(['Orders', 'Products', 'Customers', 'Summary'])
#   ProductID         ProductName     Category    Brand  StockQty  CostPrice  \
# 0   PROD001           iPhone 15  Electronics    Apple       115    2039.12
# 1   PROD002  Samsung Galaxy S24  Electronics  Samsung       385   17441.52
# 2   PROD003          OnePlus 12  Electronics  OnePlus       136   16888.39
# 3   PROD004        Boat Earbuds  Electronics     Boat        24   16863.74
# 4   PROD005     Sony Headphones  Electronics     Sony       398   18144.28
#
#    SellingPrice InStock
# 0      39324.45     Yes
# 1       6092.14     Yes
# 2      20612.26     Yes
# 3      42021.15     Yes
# 4      19313.88     Yes

# %%
bf = pd.read_excel("ecommerce_practice.xlsx", skiprows = 1 )
bf
# Out:
#      ORD00001  CUST039  PROD015  2024-01-01     Mumbai            Toys  3  \
# 0    ORD00002  CUST029  PROD027  2024-01-02  Hyderabad     Electronics  4
# 1    ORD00003  CUST015  PROD022  2024-01-04  Hyderabad          Beauty  1
# 2    ORD00004  CUST043  PROD024  2024-01-06  Bangalore            Toys  5
# 3    ORD00005  CUST008  PROD009  2024-01-08  Hyderabad       Furniture  5
# 4    ORD00006  CUST021  PROD020  2024-01-10    Chennai           Books  1
# ..        ...      ...      ...         ...        ...             ... ..
# 194  ORD00196  CUST037  PROD030  2024-12-23       Pune       Furniture  4
# 195  ORD00197  CUST033  PROD029  2024-12-25  Bangalore  Home & Kitchen  1
# 196  ORD00198  CUST042  PROD014  2024-12-27      Delhi            Toys  5
# 197  ORD00199  CUST044  PROD021  2024-12-29  Bangalore          Beauty  1
# 198  ORD00200  CUST024  PROD006  2024-12-31      Delhi       Furniture  3
#
#       5334.57   0.2   12802.97   Debit Card  Delivered    5
# ...

# %%
bf = pd.read_excel("ecommerce_practice.xlsx" , header = None  )
bf
# Out:
#            0           1          2           3          4               5   \
# 0     OrderID  CustomerID  ProductID   OrderDate       City        Category
# 1    ORD00001     CUST039    PROD015  2024-01-01     Mumbai            Toys
# 2    ORD00002     CUST029    PROD027  2024-01-02  Hyderabad     Electronics
# 3    ORD00003     CUST015    PROD022  2024-01-04  Hyderabad          Beauty
# 4    ORD00004     CUST043    PROD024  2024-01-06  Bangalore            Toys
# ..        ...         ...        ...         ...        ...             ...
# 196  ORD00196     CUST037    PROD030  2024-12-23       Pune       Furniture
# 197  ORD00197     CUST033    PROD029  2024-12-25  Bangalore  Home & Kitchen
# 198  ORD00198     CUST042    PROD014  2024-12-27      Delhi            Toys
# 199  ORD00199     CUST044    PROD021  2024-12-29  Bangalore          Beauty
# 200  ORD00200     CUST024    PROD006  2024-12-31      Delhi       Furniture
#
# ...

# %%
bf = pd.read_excel("ecommerce_practice.xlsx" , nrows = 3)
bf
# Out:
#     OrderID CustomerID ProductID   OrderDate       City     Category  \
# 0  ORD00001    CUST039   PROD015  2024-01-01     Mumbai         Toys
# 1  ORD00002    CUST029   PROD027  2024-01-02  Hyderabad  Electronics
# 2  ORD00003    CUST015   PROD022  2024-01-04  Hyderabad       Beauty
#
#    Quantity  UnitPrice  Discount  TotalAmount  PaymentMode     Status  Rating
# 0         3    5334.57      0.20     12802.97   Debit Card  Delivered       5
# 1         4   45146.13      0.05    171555.29  Net Banking  Cancelled       3
# 2         1   25360.57      0.15     21556.48  Credit Card  Delivered       3

# %%
bf = pd.read_excel("ecommerce_practice.xlsx", na_values = { "OrderDate" : [ "not available ", "n.a"],
                                                            "ProductID " : [ "not available ", "n.a", -1 ],
                                                            "Discount" : [ "not available ", "n.a"] })
bf
# Out:
#       OrderID CustomerID ProductID   OrderDate       City        Category  \
# 0    ORD00001    CUST039   PROD015  2024-01-01     Mumbai            Toys
# 1    ORD00002    CUST029   PROD027  2024-01-02  Hyderabad     Electronics
# 2    ORD00003    CUST015   PROD022  2024-01-04  Hyderabad          Beauty
# 3    ORD00004    CUST043   PROD024  2024-01-06  Bangalore            Toys
# 4    ORD00005    CUST008   PROD009  2024-01-08  Hyderabad       Furniture
# ..        ...        ...       ...         ...        ...             ...
# 195  ORD00196    CUST037   PROD030  2024-12-23       Pune       Furniture
# 196  ORD00197    CUST033   PROD029  2024-12-25  Bangalore  Home & Kitchen
# 197  ORD00198    CUST042   PROD014  2024-12-27      Delhi            Toys
# 198  ORD00199    CUST044   PROD021  2024-12-29  Bangalore          Beauty
# 199  ORD00200    CUST024   PROD006  2024-12-31      Delhi       Furniture
#
#      Quantity  UnitPrice  Discount  TotalAmount  PaymentMode     Status  \
# ...

# %%
bf.to_excel("new.xlsx" )
bf
# Out:
#       OrderID CustomerID ProductID   OrderDate       City        Category  \
# 0    ORD00001    CUST039   PROD015  2024-01-01     Mumbai            Toys
# 1    ORD00002    CUST029   PROD027  2024-01-02  Hyderabad     Electronics
# 2    ORD00003    CUST015   PROD022  2024-01-04  Hyderabad          Beauty
# 3    ORD00004    CUST043   PROD024  2024-01-06  Bangalore            Toys
# 4    ORD00005    CUST008   PROD009  2024-01-08  Hyderabad       Furniture
# ..        ...        ...       ...         ...        ...             ...
# 195  ORD00196    CUST037   PROD030  2024-12-23       Pune       Furniture
# 196  ORD00197    CUST033   PROD029  2024-12-25  Bangalore  Home & Kitchen
# 197  ORD00198    CUST042   PROD014  2024-12-27      Delhi            Toys
# 198  ORD00199    CUST044   PROD021  2024-12-29  Bangalore          Beauty
# 199  ORD00200    CUST024   PROD006  2024-12-31      Delhi       Furniture
#
#      Quantity  UnitPrice  Discount  TotalAmount  PaymentMode     Status  \
# ...

# %%
bf.to_excel("new.xlsx" , index = False )
bf
# Out:
#       OrderID CustomerID ProductID   OrderDate       City        Category  \
# 0    ORD00001    CUST039   PROD015  2024-01-01     Mumbai            Toys
# 1    ORD00002    CUST029   PROD027  2024-01-02  Hyderabad     Electronics
# 2    ORD00003    CUST015   PROD022  2024-01-04  Hyderabad          Beauty
# 3    ORD00004    CUST043   PROD024  2024-01-06  Bangalore            Toys
# 4    ORD00005    CUST008   PROD009  2024-01-08  Hyderabad       Furniture
# ..        ...        ...       ...         ...        ...             ...
# 195  ORD00196    CUST037   PROD030  2024-12-23       Pune       Furniture
# 196  ORD00197    CUST033   PROD029  2024-12-25  Bangalore  Home & Kitchen
# 197  ORD00198    CUST042   PROD014  2024-12-27      Delhi            Toys
# 198  ORD00199    CUST044   PROD021  2024-12-29  Bangalore          Beauty
# 199  ORD00200    CUST024   PROD006  2024-12-31      Delhi       Furniture
#
#      Quantity  UnitPrice  Discount  TotalAmount  PaymentMode     Status  \
# ...

# %%
bf.to_excel("new.xlsx", sheet_name = "order ", index = False)

# %%
bf.to_excel("new.xlsx", startrow = 1 , startcol = 1 , index = False )
bf
# Out:
#       OrderID CustomerID ProductID   OrderDate       City        Category  \
# 0    ORD00001    CUST039   PROD015  2024-01-01     Mumbai            Toys
# 1    ORD00002    CUST029   PROD027  2024-01-02  Hyderabad     Electronics
# 2    ORD00003    CUST015   PROD022  2024-01-04  Hyderabad          Beauty
# 3    ORD00004    CUST043   PROD024  2024-01-06  Bangalore            Toys
# 4    ORD00005    CUST008   PROD009  2024-01-08  Hyderabad       Furniture
# ..        ...        ...       ...         ...        ...             ...
# 195  ORD00196    CUST037   PROD030  2024-12-23       Pune       Furniture
# 196  ORD00197    CUST033   PROD029  2024-12-25  Bangalore  Home & Kitchen
# 197  ORD00198    CUST042   PROD014  2024-12-27      Delhi            Toys
# 198  ORD00199    CUST044   PROD021  2024-12-29  Bangalore          Beauty
# 199  ORD00200    CUST024   PROD006  2024-12-31      Delhi       Furniture
#
#      Quantity  UnitPrice  Discount  TotalAmount  PaymentMode     Status  \
# ...

# %%
bf.to_excel("new.xlsx", header=["order","cudtomer", "product", "date", "city", "cat", " quantity ", "up", " dis" , " ta", "pm", "status ", "rating "   ], index = False)
bf
# Out:
#       OrderID CustomerID ProductID   OrderDate       City        Category  \
# 0    ORD00001    CUST039   PROD015  2024-01-01     Mumbai            Toys
# 1    ORD00002    CUST029   PROD027  2024-01-02  Hyderabad     Electronics
# 2    ORD00003    CUST015   PROD022  2024-01-04  Hyderabad          Beauty
# 3    ORD00004    CUST043   PROD024  2024-01-06  Bangalore            Toys
# 4    ORD00005    CUST008   PROD009  2024-01-08  Hyderabad       Furniture
# ..        ...        ...       ...         ...        ...             ...
# 195  ORD00196    CUST037   PROD030  2024-12-23       Pune       Furniture
# 196  ORD00197    CUST033   PROD029  2024-12-25  Bangalore  Home & Kitchen
# 197  ORD00198    CUST042   PROD014  2024-12-27      Delhi            Toys
# 198  ORD00199    CUST044   PROD021  2024-12-29  Bangalore          Beauty
# 199  ORD00200    CUST024   PROD006  2024-12-31      Delhi       Furniture
#
#      Quantity  UnitPrice  Discount  TotalAmount  PaymentMode     Status  \
# ...

# %%
bf.head(10).to_excel("new.xlsx",  index = False)
bf
# Out:
#       OrderID CustomerID ProductID   OrderDate       City        Category  \
# 0    ORD00001    CUST039   PROD015  2024-01-01     Mumbai            Toys
# 1    ORD00002    CUST029   PROD027  2024-01-02  Hyderabad     Electronics
# 2    ORD00003    CUST015   PROD022  2024-01-04  Hyderabad          Beauty
# 3    ORD00004    CUST043   PROD024  2024-01-06  Bangalore            Toys
# 4    ORD00005    CUST008   PROD009  2024-01-08  Hyderabad       Furniture
# ..        ...        ...       ...         ...        ...             ...
# 195  ORD00196    CUST037   PROD030  2024-12-23       Pune       Furniture
# 196  ORD00197    CUST033   PROD029  2024-12-25  Bangalore  Home & Kitchen
# 197  ORD00198    CUST042   PROD014  2024-12-27      Delhi            Toys
# 198  ORD00199    CUST044   PROD021  2024-12-29  Bangalore          Beauty
# 199  ORD00200    CUST024   PROD006  2024-12-31      Delhi       Furniture
#
#      Quantity  UnitPrice  Discount  TotalAmount  PaymentMode     Status  \
# ...

# %%
bf[bf['Rating']>3].to_excel("new.xlsx",  index = False)

# %%
import os
import pandas as pd

 
os.chdir(r"C:\Users\RAHUL N MURTHY\Downloads")


cf = pd.read_excel("missing_data_practice.xlsx")

print(df.head())
# Out:
#             Name   Age  Gender  Math  Science  English  Attendance       City  \
# StudentID
# S001       Rahul  20.0    Male  85.0     78.0      NaN        95.0      Delhi
# S002       Priya   NaN  Female  90.0      NaN     85.0        88.0     Mumbai
# S003        Amit  22.0     NaN   NaN     82.0     79.0         NaN  Bangalore
# S004       Sneha  21.0  Female  78.0      NaN     92.0        92.0        NaN
# S005       Vikas   NaN    Male  92.0     88.0      NaN        78.0    Chennai
#
#           Grade
# StudentID
# S001          A
# S002        NaN
# S003          B
# S004          A
# S005         A+

# %%
df.set_index('StudentID' , inplace = True )
df
# Out:
#              Name   Age  Gender  Math  Science  English  Attendance  \
# StudentID
# S001        Rahul  20.0    Male  85.0     78.0      NaN        95.0
# S002        Priya   NaN  Female  90.0      NaN     85.0        88.0
# S003         Amit  22.0     NaN   NaN     82.0     79.0         NaN
# S004        Sneha  21.0  Female  78.0      NaN     92.0        92.0
# S005        Vikas   NaN    Male  92.0     88.0      NaN        78.0
# S006        Pooja  23.0     NaN  65.0     70.0     68.0         NaN
# S007        Arjun  20.0    Male   NaN     91.0     87.0        85.0
# S008        Meera   NaN  Female  88.0     76.0      NaN        90.0
# S009        Kiran  22.0    Male  72.0      NaN     80.0         NaN
# S010       Suresh  21.0     NaN  95.0     85.0     90.0        96.0
#
#                 City Grade
# StudentID
# S001           Delhi     A
# S002          Mumbai   NaN
# S003       Bangalore     B
# S004             NaN     A
# S005         Chennai    A+
# ...

# %%
new_df = df.fillna(0)
new_df
# Out:
#              Name   Age  Gender  Math  Science  English  Attendance  \
# StudentID
# S001        Rahul  20.0    Male  85.0     78.0      0.0        95.0
# S002        Priya   0.0  Female  90.0      0.0     85.0        88.0
# S003         Amit  22.0       0   0.0     82.0     79.0         0.0
# S004        Sneha  21.0  Female  78.0      0.0     92.0        92.0
# S005        Vikas   0.0    Male  92.0     88.0      0.0        78.0
# S006        Pooja  23.0       0  65.0     70.0     68.0         0.0
# S007        Arjun  20.0    Male   0.0     91.0     87.0        85.0
# S008        Meera   0.0  Female  88.0     76.0      0.0        90.0
# S009        Kiran  22.0    Male  72.0      0.0     80.0         0.0
# S010       Suresh  21.0       0  95.0     85.0     90.0        96.0
#
#                 City Grade
# StudentID
# S001           Delhi     A
# S002          Mumbai     0
# S003       Bangalore     B
# S004               0     A
# S005         Chennai    A+
# ...

# %%
new_df = df.fillna({"Gender" : "none" , "Science":0, "English": 0 ,  "Attendance": 0 , "City": "none"})
new_df
# Out:
#              Name   Age  Gender  Math  Science  English  Attendance  \
# StudentID
# S001        Rahul  20.0    Male  85.0     78.0      0.0        95.0
# S002        Priya   NaN  Female  90.0      0.0     85.0        88.0
# S003         Amit  22.0    none   NaN     82.0     79.0         0.0
# S004        Sneha  21.0  Female  78.0      0.0     92.0        92.0
# S005        Vikas   NaN    Male  92.0     88.0      0.0        78.0
# S006        Pooja  23.0    none  65.0     70.0     68.0         0.0
# S007        Arjun  20.0    Male   NaN     91.0     87.0        85.0
# S008        Meera   NaN  Female  88.0     76.0      0.0        90.0
# S009        Kiran  22.0    Male  72.0      0.0     80.0         0.0
# S010       Suresh  21.0    none  95.0     85.0     90.0        96.0
#
#                 City Grade
# StudentID
# S001           Delhi     A
# S002          Mumbai   NaN
# S003       Bangalore     B
# S004            none     A
# S005         Chennai    A+
# ...

# %%
new_df =df.ffill()
new_df
# Out:
#              Name   Age  Gender  Math  Science  English  Attendance  \
# StudentID
# S001        Rahul  20.0    Male  85.0     78.0      NaN        95.0
# S002        Priya  20.0  Female  90.0     78.0     85.0        88.0
# S003         Amit  22.0  Female  90.0     82.0     79.0        88.0
# S004        Sneha  21.0  Female  78.0     82.0     92.0        92.0
# S005        Vikas  21.0    Male  92.0     88.0     92.0        78.0
# S006        Pooja  23.0    Male  65.0     70.0     68.0        78.0
# S007        Arjun  20.0    Male  65.0     91.0     87.0        85.0
# S008        Meera  20.0  Female  88.0     76.0     87.0        90.0
# S009        Kiran  22.0    Male  72.0     76.0     80.0        90.0
# S010       Suresh  21.0    Male  95.0     85.0     90.0        96.0
#
#                 City Grade
# StudentID
# S001           Delhi     A
# S002          Mumbai     A
# S003       Bangalore     B
# S004       Bangalore     A
# S005         Chennai    A+
# ...

# %%
new_df = df.bfill()
new_df
# Out:
#              Name   Age  Gender  Math  Science  English  Attendance  \
# StudentID
# S001        Rahul  20.0    Male  85.0     78.0     85.0        95.0
# S002        Priya  22.0  Female  90.0     82.0     85.0        88.0
# S003         Amit  22.0  Female  78.0     82.0     79.0        92.0
# S004        Sneha  21.0  Female  78.0     88.0     92.0        92.0
# S005        Vikas  23.0    Male  92.0     88.0     68.0        78.0
# S006        Pooja  23.0    Male  65.0     70.0     68.0        85.0
# S007        Arjun  20.0    Male  88.0     91.0     87.0        85.0
# S008        Meera  22.0  Female  88.0     76.0     80.0        90.0
# S009        Kiran  22.0    Male  72.0     85.0     80.0        96.0
# S010       Suresh  21.0     NaN  95.0     85.0     90.0        96.0
#
#                 City Grade
# StudentID
# S001           Delhi     A
# S002          Mumbai     B
# S003       Bangalore     B
# S004         Chennai     A
# S005         Chennai    A+
# ...

# %%
df_cleaned = df.dropna(how="any")
print(df_cleaned)
# Out:
# Empty DataFrame
# Columns: [Name, Age, Gender, Math, Science, English, Attendance, City, Grade]
# Index: []

# %%
df_cleaned = df.dropna(thresh = 2)
print(df_cleaned)
# Out:
# Empty DataFrame
# Columns: [Name, Age, Gender, Math, Science, English, Attendance, City, Grade]
# Index: []

# %%
os.chdir(r"C:\Users\RAHUL N MURTHY\Downloads")

all_sheets = pd.read_excel("missing_data_advanced.xlsx", sheet_name=None)
